# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import cv2

# %%
image = cv2.imread("car_gray_wet_147750_1366x768.jpg", cv2.IMREAD_GRAYSCALE)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.IMREAD("car_gray_wet_147750_1366x768.jpg", cv2.IMREAD.GRAYSCALE)

img = cv2.resize(img,(500,500))
