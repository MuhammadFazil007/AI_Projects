# %% [markdown]
# ### Importing All Required Libraries

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from transformation import histogram

# %%
grey_image = cv2.imread(cv2.IMREAD_GRAYSCALE)
grey_image_resized = cv2.resize(grey_image,(500,500))
plt.imshow(grey_image, cmap = 'gray')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 grey_image = cv2.imread(image, cv2.IMREAD_GRAYSCALE)
#       2 grey_image_resized = cv2.resize(grey_image,(500,500))
#       3 plt.imshow(grey_image, cmap = 'gray')
#
# error: OpenCV(4.12.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object

# %%
height, width = image2.shape
hist = np.zeros((256,))
for i in range(height):
    for j in range(width):
        hist[image2[i][j]] = hist[image2[i][j]] + 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 height, width = image.shape
#       2 hist = np.zeros((256,))
#       3 for i in range(height):
#
# ValueError: too many values to unpack (expected 2)

# %%
hist_prob = hist/sum(hist)
cumulative_sum = np.cumulative_sum(hist_prob)
s = np.round(255 * cumulative_sum).astype(np.uint8)

# %%
equaliozed_image = np.zeros_like(image1)
for i in range(height):
    for j in range(width):
        equaliozed_image[i][j] = s[image1[i][j]]

# %%
equaliozed_image2 = cv2.equalizeHist(image1)
